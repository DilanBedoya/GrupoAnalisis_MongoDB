# %%
import pandas as pd

df= pd.read_csv("games.csv", index_col="app_id")
df
# Out:
#                                              title date_release   win    mac  \
# app_id
# 13500            Prince of Persia: Warrior Within™   2008-11-21  True  False
# 22364                      BRINK: Agents of Change   2011-08-03  True  False
# 113020                Monaco: What's Yours Is Mine   2013-04-24  True   True
# 226560                          Escape Dead Island   2014-11-18  True  False
# 249050                     Dungeon of the ENDLESS™   2014-10-27  True   True
# ...                                            ...          ...   ...    ...
# 2296380  I Expect You To Die 3: Cog in the Machine   2023-09-28  True  False
# 1272080                                   PAYDAY 3   2023-09-21  True  False
# 1402110                                 Eternights   2023-09-11  True  False
# 2272250                        Forgive Me Father 2   2023-10-19  True  False
# 2488510                                  FatalZone   2023-10-23  True  False
#
# ...

# %%
from pymongo import MongoClient
client= MongoClient('127.0.0.1', 27017)
print(client.server_info())
# Out:
# {'version': '7.0.4', 'gitVersion': '38f3e37057a43d2e9f41a39142681a76062d582e', 'targetMinOS': 'Windows 7/Windows Server 2008 R2', 'modules': [], 'allocator': 'tcmalloc', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [7, 0, 4, 0], 'openssl': {'running': 'Windows SChannel'}, 'buildEnvironment': {'distmod': 'windows', 'distarch': 'x86_64', 'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64', 'ccflags': '/nologo /WX /FImongo/platform/basic.h /fp:strict /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd4251 /wd4291 /we4013 /we4099 /we4930 /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++20 /Gw /Gy /Zc:inline', 'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.31.31107 for x64', 'cxxflags': '/TP', 'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF', 'target_arch': 'x86_64', 'target_os': 'windows
# ...

# %%
print(client.list_database_names())
# Out:
# ['admin', 'config', 'local', 'steam']

# %%
database = client.steam
colletion = database.list_collection_names()
print(colletion)
# Out:
# ['juegos']

# %%
#Leer datos en la database steam, collección juegos
info_games = collection.find_one({'title':'PAYDAY 3'})
print(info_games)
# Out:
# {'_id': ObjectId('658470c518ac9f357aeda5d7'), 'app_id': 1272080, 'title': 'PAYDAY 3', 'date_release': datetime.datetime(2023, 9, 21, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Mostly Negative', 'positive_ratio': 38, 'user_reviews': 29458, 'price_final': 40.0, 'price_original': 0.0, 'discount': 0.0, 'steam_deck': True}

# %%
document = {
'app_id': '666',
'title': "freec v",
'date_release':  '2010-06-25T00:00:00.000+00:00',
'win' : 'true',
'mac' : 'false',
'linux' : 'false',
'rating' : "Very Positive",
'positive_ratio' : '85',
'user_reviews' : '5169',
'price_final' : '19.99',
'price_original' : '19.99',
'discount':  '0',
'steam_deck' : 'true'}
collection.insert_one(document)
# Out:
# InsertOneResult(ObjectId('658477d56b5d47d259b76e55'), acknowledged=True)

# %%
#Crear un nuevo documento en mongoDB en la database
info_games = collection.find_one({'title':'freec v'})
print(info_games)
# Out:
# {'_id': ObjectId('658477d56b5d47d259b76e55'), 'app_id': '666', 'title': 'freec v', 'date_release': '2010-06-25T00:00:00.000+00:00', 'win': 'true', 'mac': 'false', 'linux': 'false', 'rating': 'Very Positive', 'positive_ratio': '85', 'user_reviews': '5169', 'price_final': '19.99', 'price_original': '19.99', 'discount': '0', 'steam_deck': 'true'}

# %%
document = {'app_id': 15270}
update_values = {'$set': {'price_final': 666}}
update_values = {'$set': {'title': 'El DILAN ME LA COME'}}

collection.update_one(document, update_values)
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
#Actualizar datos del database steam, collección juegos
info_games = collection.find_one({'app_id': 15270})
print(info_games)
# Out:
# {'_id': ObjectId('658470c018ac9f357aecdf2d'), 'app_id': 15270, 'title': 'El DILAN ME LA COME', 'date_release': datetime.datetime(2008, 5, 13, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Very Positive', 'positive_ratio': 85, 'user_reviews': 800, 'price_final': 666, 'price_original': 9.99, 'discount': 0.0, 'steam_deck': True}

# %%
#Borrar datos del database steam, collección juegos
datos_borrar = {'app_id':13500}
collection.delete_one(datos_borrar)
# Out:
# DeleteResult({'n': 1, 'ok': 1.0}, acknowledged=True)

# %%
info_games = collection.find_one({'app_id': 13500})
print(info_games)
# Out:
# None

# %%
#1 Consulta
collection = database['juegos']
for i in collection.find({'price_final' : 59.99}):
    print(i)
# Out:
# {'_id': ObjectId('658470c018ac9f357aecdf63'), 'app_id': 479010, 'title': 'Kodon', 'date_release': datetime.datetime(2016, 6, 3, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Mostly Positive', 'positive_ratio': 70, 'user_reviews': 245, 'price_final': 59.99, 'price_original': 59.99, 'discount': 0.0, 'steam_deck': True}
# {'_id': ObjectId('658470c018ac9f357aece080'), 'app_id': 1233260, 'title': 'FAIRY TAIL', 'date_release': datetime.datetime(2020, 7, 29, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Mostly Positive', 'positive_ratio': 72, 'user_reviews': 1178, 'price_final': 59.99, 'price_original': 59.99, 'discount': 0.0, 'steam_deck': True}
# ...

# %%
#2 Consulta
collection = database['juegos']
query = {'$and': [{'positive_ratio' : 97}, {'price_original': 29.99}]}
for i in collection.find(query):
    print(i)
# Out:
# {'_id': ObjectId('658470c018ac9f357aececdc'), 'app_id': 970560, 'title': "STEINS;GATE: My Darling's Embrace", 'date_release': datetime.datetime(2019, 12, 10, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Overwhelmingly Positive', 'positive_ratio': 97, 'user_reviews': 801, 'price_final': 11.99, 'price_original': 29.99, 'discount': 60.0, 'steam_deck': True}
# {'_id': ObjectId('658470c118ac9f357aecf852'), 'app_id': 989060, 'title': 'Virtual Home Theater Video Player', 'date_release': datetime.datetime(2019, 8, 27, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Very Positive', 'positive_ratio': 97, 'user_reviews': 79, 'price_final': 29.99, 'price_original': 29.99, 'discount': 0.0, 'steam_deck': True}
# ...

# %%
#3 Consulta
collection = database['juegos']
query = {'$and': [{'positive_ratio' : 50},{'price_final': 14.99}]}
for i in collection.find(query):
    print(i)
# Out:
# {'_id': ObjectId('658470c018ac9f357aece47f'), 'app_id': 1803780, 'title': 'Surviving the Aftermath: New Alliances', 'date_release': datetime.datetime(2021, 11, 16, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Mixed', 'positive_ratio': 50, 'user_reviews': 12, 'price_final': 14.99, 'price_original': 14.99, 'discount': 0.0, 'steam_deck': True}
# {'_id': ObjectId('658470c018ac9f357aecee94'), 'app_id': 1663570, 'title': 'HOT WHEELS™ - Batman Expansion', 'date_release': datetime.datetime(2021, 12, 2, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Mixed', 'positive_ratio': 50, 'user_reviews': 24, 'price_final': 14.99, 'price_original': 14.99, 'discount': 0.0, 'steam_deck': True}
# ...

# %%
#4 Consulta
collection = database['juegos']
query = {'$and': [{'steam_deck' : True}, {'price_original': 59.99}]}
for i in collection.find(query):
    print(i)
# Out:
# {'_id': ObjectId('658470c018ac9f357aecdf63'), 'app_id': 479010, 'title': 'Kodon', 'date_release': datetime.datetime(2016, 6, 3, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Mostly Positive', 'positive_ratio': 70, 'user_reviews': 245, 'price_final': 59.99, 'price_original': 59.99, 'discount': 0.0, 'steam_deck': True}
# {'_id': ObjectId('658470c018ac9f357aece080'), 'app_id': 1233260, 'title': 'FAIRY TAIL', 'date_release': datetime.datetime(2020, 7, 29, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Mostly Positive', 'positive_ratio': 72, 'user_reviews': 1178, 'price_final': 59.99, 'price_original': 59.99, 'discount': 0.0, 'steam_deck': True}
# ...

# %%
#5 Consulta
collection = database['juegos']
query = {'$and': [{'win' : True}, {'price_original': 59.99}, {'linux': False}]}
for i in collection.find(query):
    print(i)
# Out:
# {'_id': ObjectId('658470c018ac9f357aecdf63'), 'app_id': 479010, 'title': 'Kodon', 'date_release': datetime.datetime(2016, 6, 3, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Mostly Positive', 'positive_ratio': 70, 'user_reviews': 245, 'price_final': 59.99, 'price_original': 59.99, 'discount': 0.0, 'steam_deck': True}
# {'_id': ObjectId('658470c018ac9f357aece080'), 'app_id': 1233260, 'title': 'FAIRY TAIL', 'date_release': datetime.datetime(2020, 7, 29, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Mostly Positive', 'positive_ratio': 72, 'user_reviews': 1178, 'price_final': 59.99, 'price_original': 59.99, 'discount': 0.0, 'steam_deck': True}
# ...

# %%
#6 Consulta
collection = database['juegos']
query = {'$and': [{'win' : True}, {'price_original': 10.50}, {'linux': False}]}
for i in collection.find(query):
    print(i)
# Out:
# {'_id': ObjectId('658470c418ac9f357aed7e0b'), 'app_id': 1557690, 'title': '三国演义之蜀汉传奇', 'date_release': datetime.datetime(2021, 4, 12, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Mixed', 'positive_ratio': 57, 'user_reviews': 19, 'price_final': 10.5, 'price_original': 10.5, 'discount': 0.0, 'steam_deck': True}

# %%
#7 Consulta
collection = database['juegos']
query = {'$and': [{'win' : True}, {'price_original': 15.00}, {'linux': False}]}
for i in collection.find(query):
    print(i)
# Out:
# {'_id': ObjectId('658470c118ac9f357aed0f74'), 'app_id': 99300, 'title': 'Renegade Ops', 'date_release': datetime.datetime(2011, 10, 26, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Very Positive', 'positive_ratio': 84, 'user_reviews': 825, 'price_final': 15.0, 'price_original': 15.0, 'discount': 0.0, 'steam_deck': True}
# {'_id': ObjectId('658470c318ac9f357aed41ac'), 'app_id': 388260, 'title': 'Super Slam Dunk Touchdown', 'date_release': datetime.datetime(2015, 12, 16, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Mostly Positive', 'positive_ratio': 75, 'user_reviews': 29, 'price_final': 15.0, 'price_original': 15.0, 'discount': 0.0, 'steam_deck': True}
# ...

# %%
#8 Consulta
collection = database['juegos']
query = {'$and': [{'win' : True}, {'price_original':35.99 }, {'linux': False}]}
for i in collection.find(query):
    print(i)
# Out:
# {'_id': ObjectId('658470c418ac9f357aed6bc8'), 'app_id': 1228510, 'title': 'SOUND FORGE Audio Studio 14 Steam Edition', 'date_release': datetime.datetime(2020, 2, 14, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Mixed', 'positive_ratio': 55, 'user_reviews': 20, 'price_final': 35.99, 'price_original': 35.99, 'discount': 0.0, 'steam_deck': True}

# %%
#9 Consulta
collection = database['juegos']
query = {'$and': [{'win' : True}, {'price_original': 24.99}, {'linux': False}]}
for i in collection.find(query):
    print(i)
# Out:
# {'_id': ObjectId('658470c018ac9f357aecdfcf'), 'app_id': 716710, 'title': '東方憑依華\u3000～ Antinomy of Common Flowers.', 'date_release': datetime.datetime(2018, 1, 5, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Very Positive', 'positive_ratio': 90, 'user_reviews': 1662, 'price_final': 24.99, 'price_original': 24.99, 'discount': 0.0, 'steam_deck': True}
# {'_id': ObjectId('658470c018ac9f357aece029'), 'app_id': 1087760, 'title': 'The Gunk', 'date_release': datetime.datetime(2022, 4, 29, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Very Positive', 'positive_ratio': 84, 'user_reviews': 400, 'price_final': 24.99, 'price_original': 24.99, 'discount': 0.0, 'steam_deck': True}
# ...

# %%
#10 Consulta
collection = database['juegos']
query = {'$and': [{'win' : True}, {'price_original': 16.99}, {'linux': False}]}
for i in collection.find(query):
    print(i)
# Out:
# {'_id': ObjectId('658470c018ac9f357aece0a0'), 'app_id': 1149710, 'title': 'Tesla Force', 'date_release': datetime.datetime(2020, 11, 19, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Mostly Positive', 'positive_ratio': 78, 'user_reviews': 124, 'price_final': 16.99, 'price_original': 16.99, 'discount': 0.0, 'steam_deck': True}
# {'_id': ObjectId('658470c018ac9f357aece0e7'), 'app_id': 1175460, 'title': 'Revita', 'date_release': datetime.datetime(2021, 3, 1, 0, 0), 'win': True, 'mac': False, 'linux': False, 'rating': 'Very Positive', 'positive_ratio': 83, 'user_reviews': 1352, 'price_final': 16.99, 'price_original': 16.99, 'discount': 0.0, 'steam_deck': True}
# ...
